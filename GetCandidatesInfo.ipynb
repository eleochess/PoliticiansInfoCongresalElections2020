# %% [markdown]
# # Obteniendo los datos de todos los candidatos para las elecciones congresales del 2020

# %%
import requests
import csv
import json

# %%
candidatos = []
with open('listaCandidatosRest2.csv') as csv_candidatos:
    csv_read_candidatos = csv.reader(csv_candidatos, delimiter=';')
    line_count = 0
    for row in csv_read_candidatos:
        if line_count == 0:
            line_count = line_count + 1
        else:
            candidatos.append(row)

# %%
for can in candidatos:
    print(can[1] + " - " + can[2])
# Out:
# IR3sXSPsS8Q%253d - NORMA GISELA
# QdyPbYgwexI%253d - JOSE GABRIEL
# eHRHZj0q8xw%253d - FRANCISCO
# UWdjv4oCJp8%253d - MARINA CARMELA
# rxmJnaKZl9M%253d - EDGARD JOSE
# AhzON5EyZGY%253d - JOHNNY AMADO
# RhLw4vXmcck%253d - ROSA MARIA
# 6%252baolmqmbVU%253d - GAVINO
# oB4omXrfA0s%253d - JACOB ISRAEL
# Uhd%252fRcRpqh8%253d - HECTOR MANUEL
# WcRgWgxC7Ks%253d - MARTHA GLADYS
# DYqoSnJZBfY%253d - DIETHELL
# e6Vb5%252frAu88%253d - VALERIA CAROLINA
# 5KVRivpyOlI%253d - RICARDO ESTEBAN
# 6yh%252b9daeRTc%253d - VICTOR FELIPE
# oAuM61CaEI8%253d - RICARDO
# oxSlgIdhqNA%253d - JUAN CARLOS EUGENIO
# %252finPlq5XQPU%253d - PEDRO CARLOS
# VSx%252bBnpeQ8g%253d - CARLOS FERNANDO
# 2R5jlzB%252b7ag%253d - ZULEIKA VANNESSA
# 8HCNDyNdJdE%253d - JULIO CESAR
# psqyjPUSklo%253d - ASCELI ISABEL
# skP8fUdS66U%253d - MARIA ELENA
# OFVCz6Pl6zM%253d - MARIELLA FRANCA
# 5qXsyDlnVLA%253d - JUAN ISRAEL
# 0SmCBrDqiF8%253d - FLOR DE JESUS
# HleQoQ4aLBs%253d - FRANCISCO AMADOR
# IY9mBzua%252bpY%253d - HUGO DANIEL
# ...

# %%
with open('output/candidatos_info.csv', 'w', encoding='utf-8', newline='') as csv_info:
    with open('output/candidatos_edutec.csv', 'w', encoding='utf-8', newline='') as csv_edutec:
        with open('output/candidatos_edunouni.csv', 'w', encoding='utf-8', newline='') as csv_edunouni:
            with open('output/candidatos_eduuni.csv', 'w', encoding='utf-8', newline='') as csv_eduuni:
                with open('output/candidatos_edupost.csv', 'w', encoding='utf-8', newline='') as csv_edupost:
                    with open('output/candidatos_explab.csv', 'w', encoding='utf-8', newline='') as csv_explab:
                        with open('output/candidatos_carpar.csv', 'w', encoding='utf-8', newline='') as csv_carpar:
                            with open('output/candidatos_elepop.csv', 'w', encoding='utf-8', newline='') as csv_elepop:
                                with open('output/candidatos_renunc.csv', 'w', encoding='utf-8', newline='') as csv_renunc:
                                    with open('output/candidatos_senpen.csv', 'w', encoding='utf-8', newline='') as csv_senpen:
                                        with open('output/candidatos_senciv.csv', 'w', encoding='utf-8', newline='') as csv_senciv:
                                            with open('output/candidatos_ingresos.csv', 'w', encoding='utf-8', newline='') as csv_ingresos:
                                                with open('output/candidatos_inmuebles.csv', 'w', encoding='utf-8', newline='') as csv_inmuebles:
                                                    with open('output/candidatos_muebles.csv', 'w', encoding='utf-8', newline='') as csv_muebles:
                                                        csv_info.truncate()
                                                        csv_edutec.truncate()
                                                        csv_edunouni.truncate()
                                                        csv_eduuni.truncate()
                                                        csv_edupost.truncate()
                                                        csv_explab.truncate()
                                                        csv_carpar.truncate()
                                                        csv_elepop.truncate()
                                                        csv_renunc.truncate()
                                                        csv_senpen.truncate()
                                                        csv_senciv.truncate()
                                                        csv_ingresos.truncate()
                                                        csv_inmuebles.truncate()
                                                        csv_muebles.truncate()

                                                        fw_info = csv.writer(csv_info, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_edutec = csv.writer(csv_edutec, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_edunouni = csv.writer(csv_edunouni, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_eduuni = csv.writer(csv_eduuni, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_edupost = csv.writer(csv_edupost, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_explab = csv.writer(csv_explab, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_carpar = csv.writer(csv_carpar, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_elepop = csv.writer(csv_elepop, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_renunc = csv.writer(csv_renunc, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_senpen = csv.writer(csv_senpen, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_senciv = csv.writer(csv_senciv, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_ingresos = csv.writer(csv_ingresos, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_inmuebles = csv.writer(csv_inmuebles, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)
                                                        fw_muebles = csv.writer(csv_muebles, delimiter = ';', quotechar = '|', quoting = csv.QUOTE_MINIMAL)

                                                        fw_info.writerow(['ID_CANDIDATO', 'ID_ENCRIPTADO', 'NOMBRES', 'APE_PAT', 'APE_MAT', 'DNI', 'REGION', 'PARTIDO', 'POSICION', 'FOTO', 'CARGO_POSTULA', 'SEXO', 'FECHA_NAC', 'PAIS_NAC', 'DEPARTAMENTO_NAC', 'PROVINCIA_NAC', 'DISTRITO_NAC', 'ID_HOJAVIDA', 'INFO_BASICA', 'TIENE_PRIMARIA', 'CONCLUYO_PRIMARIA', 'TIENE_SECUNDARIA', 'CONCLUYO_SECUNDARIA', 'TIENE_ESTUDIOS_TECNICOS', 'TIENE_ESTUDIOS_NO_UNIVERSITARIOS', 'TIENE_ESTUDIOS_UNIVERSITARIOS', 'TIENE_ESTUDIOS_POSTGRADO', 'TIENE_EXPERIENCIA_LABORAL', 'TIENE_CARGOS_PARTIDARIOS', 'TIENE_ELECCION_POPULAR', 'TIENE_RENUNCIAS', 'TIENE_SENTENCIA_PENAL', 'TIENE_SENTENCIA_CIVIL', 'TIENE_INGRESOS', 'TIENE_INMUEBLES', 'TIENE_MUEBLES'])
                                                        fw_edutec.writerow(['ID_CANDIDATO', 'CENTRO_ESTUDIOS', 'CARRERA', 'CONCLUIDO'])
                                                        fw_edunouni.writerow(['ID_CANDIDATO', 'CENTRO_ESTUDIOS', 'CARRERA', 'CONCLUIDO'])
                                                        fw_eduuni.writerow(['ID_CANDIDATO', 'UNIVERSIDAD', 'CARRERA', 'CONCLUIDO', 'BACHILLER', 'TITULO'])
                                                        fw_edupost.writerow(['ID_CANDIDATO', 'CENTRO_ESTUDIOS', 'ESPECIALIDAD', 'CONCLUIDO', 'EGRESADO'])
                                                        fw_explab.writerow(['ID_CANDIDATO', 'CENTRO_TRABAJO', 'OCUPACION', 'DESDE', 'HASTA'])
                                                        fw_carpar.writerow(['ID_CANDIDATO', 'ORGANIZACION_POLITICA', 'CARGO_PARTIDARIO', 'DESDE', 'HASTA'])
                                                        fw_elepop.writerow(['ID_CANDIDATO', 'ORGANIZACION_POLITICA', 'CARGO_ELECCION', 'DESDE', 'HASTA'])
                                                        fw_renunc.writerow(['ID_CANDIDATO', 'ORGANIZACION_POLITICA', 'ANIO', 'FECHA_RENUNCIA'])
                                                        fw_senpen.writerow(['ID_CANDIDATO', 'DELITO', 'PENA_O_FALLO', 'FECHA_SENTENCIA', 'MODALIDAD', 'CUMPLIMIENTO'])
                                                        fw_senciv.writerow(['ID_CANDIDATO', 'DELITO', 'PENA_O_FALLO'])
                                                        fw_ingresos.writerow(['ID_CANDIDATO', 'REMUN_BRUTA_ANUAL_PUBLICA', 'REMUN_BRUTA_ANUAL_PRIVADA', 'RENTA_BRUTA_ANUAL_INDIV_PUBLICA', 'RENTA_BRUTA_ANUAL_INDIV_PRIVADA', 'OTROS_INGRESOS_ANUALES_PUBLICA', 'OTROS_INGRESOS_ANUALES_PRIVADA', 'TOTAL_REMUN_BRUTA_ANUAL', 'TOTAL_RENTA_BRUTA_ANUAL', 'TOTAL_OTROS_INGRESOS_ANUALES', 'TOTAL_GENERAL'])
                                                        fw_inmuebles.writerow(['ID_CANDIDATO', 'TIPO_BIEN', 'VALOR'])
                                                        fw_muebles.writerow(['ID_CANDIDATO', 'BIEN', 'VALOR'])

                                                        can_count = 0
                                                        for can in candidatos:
                                                            url = "https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=" + can[1]
                                                            can_count = can_count + 1
                                                            print(str(can_count) + " - " + url)

                                                            response = requests.get(url)
                                                            json_res = response.json()

                                                            if json_res["result"] == 0:
                                                                continue

                                                            par_tiene_edutec = 0
                                                            par_tiene_edunouni = 0
                                                            par_tiene_eduuni = 0
                                                            par_tiene_edupost = 0
                                                            par_tiene_explab = 0
                                                            par_tiene_carpar = 0
                                                            par_tiene_elepop = 0
                                                            par_tiene_renunc = 0
                                                            par_tiene_senpen = 0
                                                            par_tiene_senciv = 0
                                                            par_tiene_ingresos = 0
                                                            par_tiene_inmuebles = 0
                                                            par_tiene_muebles = 0

                                                            for edutec in json_res["data"]["Data"]["EDUCACIONTECNICAS"]:
                                                                if edutec["TXCENESTUDIOTECNICO"] != "" and edutec["TXCENESTUDIOTECNICO"] is not None:
                                                                    par_tiene_edutec = 1
                                                                    fw_edutec.writerow([
                                                                        can[0],
                                                                        edutec["TXCENESTUDIOTECNICO"],
                                                                        edutec["TXCARRERATECNICO"],
                                                                        edutec["TXCONCLUYO"]
                                                                    ])

                                                            for edunouni in json_res["data"]["Data"]["EDUCACIONNOUNIVERSITARIAS"]:
                                                                if edunouni["TXCENTROESTUDIONOUNI"] != "" and edunouni["TXCENTROESTUDIONOUNI"] is not None:
                                                                    par_tiene_edunouni = 1
                                                                    fw_edunouni.writerow([
                                                                        can[0],
                                                                        edunouni["TXCENTROESTUDIONOUNI"],
                                                                        edunouni["TXCARRERANOUNI"],
                                                                        edunouni["TXCONCLUYO"]
                                                                    ])

                                                            for eduuni in json_res["data"]["Data"]["EDUCACIONUNIVERSITARIAS"]:
                                                                if eduuni["TXUNIVERSIDAD"] != "" and eduuni["TXUNIVERSIDAD"] is not None:
                                                                    par_tiene_eduuni = 1
                                                                    fw_eduuni.writerow([
                                                                        can[0],
                                                                        eduuni["TXUNIVERSIDAD"],
                                                                        eduuni["TXCARRERAUNI"],
                                                                        eduuni["TXCONCLUYO"],
                                                                        eduuni["TXBACHILLER"],
                                                                        eduuni["TXTITULO"]
                                                                    ])

                                                            for edupost in json_res["data"]["Data"]["EDUCACIONPOSTGRADOS"]:
                                                                if edupost["TXCENESTUDIOPOSGRADO"] != "" and edupost["TXCENESTUDIOPOSGRADO"] is not None:
                                                                    par_tiene_edupost = 1
                                                                    fw_edupost.writerow([
                                                                        can[0],
                                                                        edupost["TXCENESTUDIOPOSGRADO"],
                                                                        edupost["TXESPECIALIDADPOSGRADO"],
                                                                        edupost["TXCONCLUYO"],
                                                                        edupost["TXEGRESADO"]
                                                                    ])

                                                            for explab in json_res["data"]["Data"]["EXPERIENCIAS"]:
                                                                if explab["TXCENTROTRABAJO"] != "" and explab["TXCENTROTRABAJO"] is not None:
                                                                    par_tiene_explab = 1
                                                                    fw_explab.writerow([
                                                                        can[0],
                                                                        explab["TXCENTROTRABAJO"],
                                                                        explab["TXOCUPACIONPROFESION"],
                                                                        explab["TXANIOTRABAJODESDE"],
                                                                        explab["TXANIOTRABAJOHASTA"]
                                                                    ])

                                                            for carpar in json_res["data"]["Data"]["CARGOPARTIDARIOS"]:
                                                                if carpar["TXORGPOLCARGOPARTIDARIO"] != "" and carpar["TXORGPOLCARGOPARTIDARIO"] is not None:
                                                                    par_tiene_carpar = 1
                                                                    fw_carpar.writerow([
                                                                        can[0],
                                                                        carpar["TXORGPOLCARGOPARTIDARIO"],
                                                                        carpar["TXCARGOPARTIDARIO"],
                                                                        carpar["TXANIOCARGOPARTIDESDE"],
                                                                        carpar["TXANIOCARGOPARTIHASTA"]
                                                                    ])

                                                            for elepop in json_res["data"]["Data"]["CARGOELECCIONS"]:
                                                                if elepop["TXORGPOLCARGOELEC"] != "" and elepop["TXORGPOLCARGOELEC"] is not None:
                                                                    par_tiene_elepop = 1
                                                                    fw_elepop.writerow([
                                                                        can[0],
                                                                        elepop["TXORGPOLCARGOELEC"],
                                                                        elepop["TXCARGOELECCION2"],
                                                                        elepop["TXANIOCARGOELECDESDE"],
                                                                        elepop["TXANIOCARGOELECHASTA"]
                                                                    ])

                                                            for renunc in json_res["data"]["Data"]["RENUNCIAS"]:
                                                                if renunc["TXORGPOLRENUNCIAOP"] != "" and renunc["TXORGPOLRENUNCIAOP"] is not None:
                                                                    par_tiene_renunc = 1
                                                                    fw_renunc.writerow([
                                                                        can[0],
                                                                        renunc["TXORGPOLRENUNCIAOP"],
                                                                        renunc["TXANIORENUNCIAOP"],
                                                                        renunc["FEREGISTRO"]
                                                                    ])

                                                            for senpen in json_res["data"]["Data"]["SENTENCIAPENALS"]:
                                                                if senpen["TXDELITOPENAL"] != "" and senpen["TXDELITOPENAL"] is not None:
                                                                    par_tiene_senpen = 1
                                                                    fw_senpen.writerow([
                                                                        can[0],
                                                                        senpen["TXDELITOPENAL"],
                                                                        senpen["TXFALLOPENAL"],
                                                                        senpen["FESENTENCIAPENAL"],
                                                                        senpen["TXMODALIDAD"],
                                                                        senpen["TXCUMPLEFALLO"]
                                                                    ])

                                                            for senciv in json_res["data"]["Data"]["SENTENCIACIVILS"]:
                                                                if senciv["TXMATERIASENTENCIA"] != "" and senciv["TXMATERIASENTENCIA"] is not None:
                                                                    par_tiene_senciv = 1
                                                                    fw_senciv.writerow([
                                                                        can[0],
                                                                        senciv["TXMATERIASENTENCIA"],
                                                                        senciv["TXFALLOOBLIGA"]
                                                                    ])
                                                                    
                                                            for ingres in json_res["data"]["Data"]["INGRESOS"]:
                                                                if ingres["FGTENGOINGRESOS"] == 1:
                                                                    par_tiene_ingresos = 1
                                                                    fw_ingresos.writerow([
                                                                        can[0],
                                                                        ingres["FLREMUBRUTAPUBLICO"],
                                                                        ingres["FLREMUBRUTAPRIVADO"],
                                                                        ingres["FLRENTAINDIVIDUALPUBLICO"],
                                                                        ingres["FLRENTAINDIVIDUALPRIVADO"],
                                                                        ingres["FLOTROINGRESOPUBLICO"],
                                                                        ingres["FLOTROINGRESOPRIVADO"],
                                                                        ingres["TOTALREMBRUTA"],
                                                                        ingres["TOTALRENTA"],
                                                                        ingres["TOTALOTRO"],
                                                                        ingres["TOTAL"]
                                                                    ])
                                                                    
                                                            for inmuebl in json_res["data"]["Data"]["BIENINMUEBLES"]:
                                                                if inmuebl["FGTENGOINMUEBLE"] == 1:
                                                                    par_tiene_inmuebles = 1
                                                                    fw_inmuebles.writerow([
                                                                        can[0],
                                                                        inmuebl["TXTIPOBIENINMUEBLE"],
                                                                        inmuebl["FLAUTOVALUO"]
                                                                    ])
                                                                    
                                                            for mueble in json_res["data"]["Data"]["BIENMUEBLES"]:
                                                                if mueble["FGTENGOBIENMUEBLE"] == 1:
                                                                    par_tiene_muebles = 1
                                                                    fw_muebles.writerow([
                                                                        can[0],
                                                                        mueble["TXVEHICULO"],
                                                                        mueble["FLVALOR"]
                                                                    ])
                                                            
                                                            fw_info.writerow([
                                                                can[0],
                                                                can[1],
                                                                can[2],
                                                                can[3],
                                                                can[4],
                                                                can[5],
                                                                can[6],
                                                                can[7],
                                                                can[8],
                                                                can[9],
                                                                json_res["data"]["Data"]["TXCARGOELECCION"],
                                                                json_res["data"]["Data"]["TXSEXO"],
                                                                json_res["data"]["Data"]["FENACIMIENTO"],
                                                                json_res["data"]["Data"]["TXPAISNACIMIENTO"],
                                                                json_res["data"]["Data"]["TXNACIDEPARTAMENTO"],
                                                                json_res["data"]["Data"]["TXNACIPROVINCIA"],
                                                                json_res["data"]["Data"]["TXNACIDISTRITO"],
                                                                json_res["data"]["Data"]["IDHOJAVIDA"],

                                                                json_res["data"]["Data"]["EDUCACIONBASICAS"][0]["TXTIENEBASICA"],
                                                                json_res["data"]["Data"]["EDUCACIONBASICAS"][0]["TXTIENEPRIMARIA"],
                                                                json_res["data"]["Data"]["EDUCACIONBASICAS"][0]["TXCONCLUYOPRIMARIA"],
                                                                json_res["data"]["Data"]["EDUCACIONBASICAS"][0]["TXTIENESECUNDARIA"],
                                                                json_res["data"]["Data"]["EDUCACIONBASICAS"][0]["TXCONCLUYOSECUNDARIA"],

                                                                par_tiene_edutec,
                                                                par_tiene_edunouni,
                                                                par_tiene_eduuni,
                                                                par_tiene_edupost,
                                                                par_tiene_explab,
                                                                par_tiene_carpar,
                                                                par_tiene_elepop,
                                                                par_tiene_renunc,
                                                                par_tiene_senpen,
                                                                par_tiene_senciv,
                                                                par_tiene_ingresos,
                                                                par_tiene_inmuebles,
                                                                par_tiene_muebles
                                                            ])
# Out:
# 1 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=IR3sXSPsS8Q%253d
# 2 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=QdyPbYgwexI%253d
# 3 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=eHRHZj0q8xw%253d
# 4 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=UWdjv4oCJp8%253d
# 5 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=rxmJnaKZl9M%253d
# 6 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=AhzON5EyZGY%253d
# 7 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=RhLw4vXmcck%253d
# 8 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=6%252baolmqmbVU%253d
# 9 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=oB4omXrfA0s%253d
# 10 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=Uhd%252fRcRpqh8%253d
# 11 - https://votoinformado.jne.gob.pe/voto/HojaVida/CargarHojaVida?id=WcRgWgxC7Ks%253d
# ...
